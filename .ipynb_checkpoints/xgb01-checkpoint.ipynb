# %%
import numpy as np
import pandas as pd
from datetime import datetime, timedelta
import warnings
warnings.filterwarnings("ignore")

import plotly.express as px
import plotly.io as pio
pio.renderers.default = 'notebook_connected'

import matplotlib.pyplot as plt
import seaborn as sns

# matplotlib 한글폰트 깨지는 현상 해결
from matplotlib import font_manager as fm
from matplotlib import rc
font_path = 'C:/Windows/Fonts/malgun.ttf'
font_prop_size20 = fm.FontProperties(fname=font_path, size=20)
font_prop_size15 = fm.FontProperties(fname=font_path, size=15)
font_prop_size10 = fm.FontProperties(fname=font_path, size=10)
rc('font', family=fm.FontProperties(fname=font_path).get_name())


# 데이터 로드
Time = pd.read_csv('data/Time.csv')
TimeProvince = pd.read_csv('data/TimeProvince1.csv')
Region = pd.read_csv('data/Region.csv')
PatientInfo = pd.read_csv('data/PatientInfo.csv')

# %%
TimeProvince
# Out:
#           date  time          province  confirmed  released  deceased
# 0   2020-01-31    16             Seoul          4         0         0
# 1   2020-01-31    16             Busan          0         0         0
# 2   2020-01-31    16             Daegu          0         0         0
# 3   2020-01-31    16           Incheon          1         0         0
# 4   2020-01-31    16           Gwangju          0         0         0
# ..         ...   ...               ...        ...       ...       ...
# 80  2020-05-31     0      Jeollabuk-do          3        19         0
# 81  2020-05-31     0      Jeollanam-do          4        17         0
# 82  2020-05-31     0  Gyeongsangbuk-do         14      1295        54
# 83  2020-05-31     0  Gyeongsangnam-do          6       121         0
# 84  2020-05-31     0           Jeju-do          2        13         0
#
# [85 rows x 6 columns]

# %%
TP_confirmed = TimeProvince.drop(['time','released','deceased'], axis=1)

# %%
TP_confirmed['month']=TP_confirmed['date'].str[6:7]

# %%
TP_confirmed
# Out:
#           date          province  confirmed month
# 0   2020-01-31             Seoul          4     1
# 1   2020-01-31             Busan          0     1
# 2   2020-01-31             Daegu          0     1
# 3   2020-01-31           Incheon          1     1
# 4   2020-01-31           Gwangju          0     1
# ..         ...               ...        ...   ...
# 80  2020-05-31      Jeollabuk-do          3     5
# 81  2020-05-31      Jeollanam-do          4     5
# 82  2020-05-31  Gyeongsangbuk-do         14     5
# 83  2020-05-31  Gyeongsangnam-do          6     5
# 84  2020-05-31           Jeju-do          2     5
#
# [85 rows x 4 columns]

# %%
TP_df = TP_confirmed.pivot('province','date','confirmed')

# %%
TP_df
# Out:
# date               2020-01-31  2020-02-29  2020-03-31  2020-04-30  2020-05-31
# province
# Busan                       0          80          39          18          10
# Chungcheongbuk-do           0          10          34           1          15
# Chungcheongnam-do           0          55          73          15           3
# Daegu                       0        2236        4448         168          31
# Daejeon                     0          13          23           4           6
# Gangwon-do                  0           7          29          17           4
# Gwangju                     0           9          11          10           2
# Gyeonggi-do                 5          77         394         200         164
# Gyeongsangbuk-do            0         488         812          65          14
# Gyeongsangnam-do            0          59          37          21           6
# Incheon                     1           5          58          29         113
# ...

# %%
sns.heatmap(df, annot=True, fmt='d')

plt.title('Annoteat cell with numeric value', fontsize=20)

plt.show()
